# %% [markdown]
# Завдання
#
# Створити скрипт Python або Notebook з наступним функціоналом:
#
# 1.Зчитати та завантажити тестове чорно-біле та кольорове зображення.
# 2.Відобразити чорно-біле та кольорове зображення.
# 3.Перетворити зображення з колірної моделі BGR в колірні моделі RGB і HSV та відобразити.
# 4.Окремо відобразити колірні канали для зображень із колірними моделями RGB та HSV.
# 5.Скопіювати область інтересу (Region of Interest) чорно-білого зображення, використовуючи наступні діапазони 0:img.shape[0]/2, 0:img.shape[1]/2.
# 6.Зберегти область інтересу (Region of Interest).
#
# Додаткові завдання:
#
# 1.Перетворити зображення з колірної моделі BGR в колірну модель HSV за допомогою формул.
# 2.Реалізувати функцію для визначення колірної відстані (Delta E76, Delta E94).
#
# Import modules

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Зчитати та завантажити тестове чорно-біле та кольорове зображення.

# %%
img_bw = cv2.imread("./2.JPG", cv2.IMREAD_GRAYSCALE)
img_color = cv2.imread("./1.JPG", cv2.COLOR_BGR2RGB)

# %% [markdown]
# Відобразити чорно-біле та кольорове зображення.

# %%
print(img_bw)
print(img_color)
# Out:
# [[ 8  5  4 ... 28 26 26]
#  [14  6  4 ... 32 28 25]
#  [10  5 12 ... 39 34 27]
#  ...
#  [81 81 80 ... 48 46 46]
#  [77 78 78 ... 45 44 44]
#  [77 76 74 ... 42 43 44]]
# [[[218 200 178]
#   [215 198 176]
#   [213 196 173]
#   ...
#   [ 61  29 230]
#   [ 59  28 226]
#   [ 61  30 229]]
#
#  [[220 203 180]
#   [218 200 178]
#   [215 198 176]
#   ...
#   [ 63  32 233]
#   [ 63  33 231]
#   [ 57  27 225]]
#
#  [[222 205 183]
#   [220 203 180]
#   [218 200 178]
#   ...
#   [ 57  26 227]
#   [ 59  28 226]
#   [ 66  35 233]]
#
#  ...
#
#  [[200 212 197]
#   [201 213 198]
#   [201 213 198]
#   ...
#   [206 208 221]
#   [206 208 221]
#   [205 207 220]]
#
#  [[201 213 198]
#   [201 213 198]
#   [202 214 199]
#   ...
#   [208 211 224]
#   [208 211 222]
#   [207 210 221]]
#
#  [[201 213 198]
#   [202 214 199]
#   [205 217 201]
#   ...
#   [211 213 226]
#   [211 214 225]
#   [209 213 223]]]

# %%
plt.figure(figsize=(5, 5))
plt.imshow(img_bw, cmap='gray')
plt.show();

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img_color)
plt.show();

# %% [markdown]
# Перетворити зображення з колірної моделі BGR в колірні моделі RGB і HSV та відобразити.

# %%
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show();

# %%
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2HSV))
plt.show();

# %% [markdown]
# Окремо відобразити колірні канали для зображень із колірними моделями RGB та HSV.

# %%
img_rgb = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))

plt.subplot(131);
R = np.zeros(img_rgb.shape, dtype='uint8')
R[:, :, 0] = img_rgb[:, :, 0]
plt.imshow(R)

plt.subplot(132);
G = np.zeros(img_rgb.shape, dtype='uint8')
G[:, :, 1] = img_rgb[:, :, 1]
plt.imshow(G)

plt.subplot(133);
B = np.zeros(img_rgb.shape, dtype='uint8')
B[:, :, 2] = img_rgb[:, :, 2]
plt.imshow(B)

plt.show()

# %%
img_hsv = cv2.cvtColor(img_color, cv2.COLOR_BGR2HSV)
plt.figure(figsize=(10, 10))

plt.subplot(131);
R = np.zeros(img_hsv.shape, dtype='uint8')
R[:, :, 0] = img_hsv[:, :, 0]
plt.imshow(R)

plt.subplot(132);
G = np.zeros(img_hsv.shape, dtype='uint8')
G[:, :, 1] = img_hsv[:, :, 1]
plt.imshow(G)

plt.subplot(133);
B = np.zeros(img_hsv.shape, dtype='uint8')
B[:, :, 2] = img_hsv[:, :, 2]
plt.imshow(B)

plt.show()

# %% [markdown]
# Скопіювати область інтересу (Region of Interest) чорно-білого зображення, використовуючи наступні діапазони 0:img.shape[0]/2, 0:img.shape[1]/2.

# %%
img_crop_bw = img_bw[0:int(img_bw.shape[0]/2), 0:int(img_bw.shape[1]/2)]
print(img_crop_bw)
plt.imshow(img_crop_bw, cmap='gray')
plt.show()
# Out:
# [[  8   5   4 ...  27  45  23]
#  [ 14   6   4 ...   1   2   2]
#  [ 10   5  12 ...  11   7   5]
#  ...
#  [  0   0   0 ... 120 115 110]
#  [  0   0   0 ... 106 108 107]
#  [  0   0   0 ... 114 108 107]]

# %% [markdown]
# Зберегти область інтересу (Region of Interest).

# %%
cv2.imwrite("./save_ex1.png", img_crop_bw)
# Out:
# True
